# %%
import pandas as pd
import io

data = """Asset,Exposure,Risk_Weight,Tier1_Capital,Tier2_Capital
Corporate Loans,5000000,0.4,250000,60000
Retail Loans,3000000,0.70,200000,50000
Sovereign Bonds,2000000,0.05,150000,30000
Mortgage Loans,4000000,0.20,200000,40000
Trading Book,1500000,0.80,100000,20000
"""

df = pd.read_csv(io.StringIO(data))
display(df)
# Out:
#              Asset  Exposure  Risk_Weight  Tier1_Capital  Tier2_Capital
# 0  Corporate Loans   5000000         0.40         250000          60000
# 1     Retail Loans   3000000         0.70         200000          50000
# 2  Sovereign Bonds   2000000         0.05         150000          30000
# 3   Mortgage Loans   4000000         0.20         200000          40000
# 4     Trading Book   1500000         0.80         100000          20000
